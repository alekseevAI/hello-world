# %% [markdown]
# ### Learn Pandas in 10 minutes
#
# [https://pandas.pydata.org/pandas-docs/stable/10min.html](https://pandas.pydata.org/pandas-docs/stable/10min.html)

# %% [markdown]
# ### Import pandas, numpy and matplotlib

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Import the dataset from this [address]('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv')

# %%
url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv'
    
df = pd.read_csv(url, sep = '\t')

# %% [markdown]
# ### Show the first 10 entries

# %%
df.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# 5  [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...    $10.98
# 6                                                NaN     $1.69
# 7  [Tomatillo Red Chili Salsa, [Fajita Vegetables...    $11.75
# 8  [Tomatillo Green Chili Salsa, [Pinto Beans, Ch...     $9.25
# 9  [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...     $9.25

# %% [markdown]
# ### What is the number of observations in the dataset?

# %%
len(df)
# Out:
# 4622

# %% [markdown]
# ### What is the number of columns in the dataset?

# %%
df.shape
# Out:
# (4622, 5)

# %% [markdown]
# ### Which was the most-ordered item and how many times it was ordered?

# %%
vals = (df.groupby('item_name', as_index = False)['quantity']).count()
vals.sort_values('quantity', ascending=False).head(1)
# Out:
#        item_name  quantity
# 17  Chicken Bowl       726

# %% [markdown]
# ### How many different items are sold?

# %%
len(vals)
# Out:
# 50

# %% [markdown]
# ### How many items were orderd in total?

# %%
df['quantity'].sum()
# Out:
# 4972

# %% [markdown]
# ### Turn the item price into a float

# %%
df['item_price_float']=df['item_price'].apply(lambda x: float(x[1:]))
df.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price  \
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
#
#    item_price_float
# 0              2.39
# 1              3.39
# 2              3.39
# 3              2.39
# 4             16.98

# %% [markdown]
# ### What is the price of each item?

# %%
df.groupby('item_name')['item_price_float'].mean()
# Out:
# item_name
# 6 Pack Soft Drink                         6.610185
# Barbacoa Bowl                            10.187273
# Barbacoa Burrito                          9.832418
# Barbacoa Crispy Tacos                    10.928182
# Barbacoa Salad Bowl                      10.640000
# Barbacoa Soft Tacos                      10.018400
# Bottled Water                             1.867654
# Bowl                                     14.800000
# Burrito                                   7.400000
# Canned Soda                               1.320577
# Canned Soft Drink                         1.457641
# Carnitas Bowl                            10.833971
# Carnitas Burrito                         10.132712
# Carnitas Crispy Tacos                    11.137143
# Carnitas Salad                            8.990000
# Carnitas Salad Bowl                      11.056667
# Carnitas Soft Tacos                       9.398500
# Chicken Bowl                             10.113953
# Chicken Burrito                          10.082857
# Chicken Crispy Tacos                     10.045319
# Chicken Salad                             9.010000
# Chicken Salad Bowl                       11.170455
# Chicken Soft Tacos                        9.635565
# Chips                                     2.342844
# Chips and Fresh Tomato Salsa              3.285091
# Chips and Guacamole                       4.595073
# Chips and Mild Fresh Tomato Salsa         3.000000
# Chips and Roasted Chili Corn Salsa        3.084091
# Chips and Roasted Chili-Corn Salsa        2.390000
# Chips and Tomatillo Green Chili Salsa     3.087209
# Chips and Tomatillo Red Chili Salsa       3.072917
# Chips and Tomatillo-Green Chili Salsa     2.544194
# Chips and Tomatillo-Red Chili Salsa       2.987500
# Crispy Tacos                              7.400000
# Izze                                      3.390000
# Nantucket Nectar                          3.641111
# Salad                                     7.400000
# Side of Chips                             1.840594
# Steak Bowl                               10.711801
# Steak Burrito                            10.465842
# Steak Crispy Tacos                       10.209714
# Steak Salad                               8.915000
# Steak Salad Bowl                         11.847931
# Steak Soft Tacos                          9.746364
# Veggie Bowl                              10.211647
# Veggie Burrito                            9.839684
# Veggie Crispy Tacos                       8.490000
# Veggie Salad                              8.490000
# Veggie Salad Bowl                        10.138889
# Veggie Soft Tacos                        10.565714
# Name: item_price_float, dtype: float64

# %% [markdown]
# ### How much was the revenue for the period in the dataset?

# %%
(df['quantity']*df['item_price_float']).sum()
# Out:
# 39237.02

# %% [markdown]
# ### How many orders were made in the period?

# %%
df['order_id'].value_counts().shape
# Out:
# (1834,)

# %% [markdown]
# ### What is the average revenue amount per order?

# %%
df['item*quantity'] = df['item_price_float'] * df['quantity']
v = (df.groupby('order_id')['item*quantity'].sum()).mean()
v
# Out:
# 21.394231188658654

# %% [markdown]
# ### Merge the table ```dfa``` that contains order date and order id with ```df``` and plot daily revenue

# %%
dfa = pd.DataFrame({"date": np.random.choice(pd.date_range(start="20170101", end="20170201"), size=1800),
                   "order_id": np.arange(1800)})
g = pd.merge(dfa, df)
daily_revenue = (g.groupby('date')['item*quantity']).sum()
plt.figure(figsize = (20, 10))
plt.plot(daily_revenue)
plt.xlabel('Date')
plt.ylabel('Daily revenue')
# Out:
# Text(0, 0.5, 'Daily revenue')

# %%
g
# Out:
#            date  order_id  quantity                              item_name  \
# 0    2017-01-18         1         1           Chips and Fresh Tomato Salsa
# 1    2017-01-18         1         1                                   Izze
# 2    2017-01-18         1         1                       Nantucket Nectar
# 3    2017-01-18         1         1  Chips and Tomatillo-Green Chili Salsa
# 4    2017-01-14         2         2                           Chicken Bowl
# 5    2017-01-14         3         1                           Chicken Bowl
# 6    2017-01-14         3         1                          Side of Chips
# 7    2017-01-28         4         1                          Steak Burrito
# 8    2017-01-28         4         1                       Steak Soft Tacos
# 9    2017-01-22         5         1                          Steak Burrito
# 10   2017-01-22         5         1                    Chips and Guacamole
# 11   2017-01-21         6         1                   Chicken Crispy Tacos
# 12   2017-01-21         6         1                     Chicken Soft Tacos
# 13   2017-01-03         7         1                           Chicken Bowl
# 14   2017-01-03         7         1                    Chips and Guacamole
# 15   2017-01-22         8         1  Chips and Tomatillo-Green Chili Salsa
# 16   2017-01-22         8         1                        Chicken Burrito
# 17   2017-01-04         9         1                        Chicken Burrito
# 18   2017-01-04         9         2                            Canned Soda
# 19   2017-01-20        10         1                           Chicken Bowl
# 20   2017-01-20        10         1                    Chips and Guacamole
# 21   2017-01-30        11         1                       Barbacoa Burrito
# 22   2017-01-30        11         1                       Nantucket Nectar
# 23   2017-01-08        12         1                        Chicken Burrito
# 24   2017-01-08        12         1                                   Izze
# 25   2017-01-17        13         1           Chips and Fresh Tomato Salsa
# 26   2017-01-17        13         1                           Chicken Bowl
# 27   2017-01-23        14         1                       Carnitas Burrito
# 28   2017-01-23        14         1                            Canned Soda
# 29   2017-01-08        15         1                        Chicken Burrito
# ...         ...       ...       ...                                    ...
# 4497 2017-01-29      1788         1                                  Chips
# 4498 2017-01-15      1789         1                           Chicken Bowl
# 4499 2017-01-15      1789         2                      Canned Soft Drink
# 4500 2017-01-15      1789         1                          Carnitas Bowl
# 4501 2017-01-22      1790         1                      Canned Soft Drink
# 4502 2017-01-22      1790         1                     Chicken Soft Tacos
# 4503 2017-01-22      1790         1           Chips and Fresh Tomato Salsa
# 4504 2017-01-15      1791         1                          Carnitas Bowl
# 4505 2017-01-15      1791         1                                  Chips
# 4506 2017-01-05      1792         1                           Chicken Bowl
# 4507 2017-01-05      1792         1                          Bottled Water
# 4508 2017-01-02      1793         1                          Steak Burrito
# 4509 2017-01-02      1793         1                                  Chips
# 4510 2017-01-02      1793         1                          Barbacoa Bowl
# 4511 2017-01-11      1794         1                           Chicken Bowl
# 4512 2017-01-11      1794         1                    Chips and Guacamole
# 4513 2017-01-11      1794         1                      Canned Soft Drink
# 4514 2017-01-08      1795         1                     Chicken Soft Tacos
# 4515 2017-01-08      1795         1                    Chips and Guacamole
# 4516 2017-01-08      1795         1                      Canned Soft Drink
# 4517 2017-01-21      1796         1                          Bottled Water
# 4518 2017-01-21      1796         1                             Steak Bowl
# 4519 2017-01-16      1797         1                         Veggie Burrito
# 4520 2017-01-16      1797         1                     Chicken Salad Bowl
# 4521 2017-01-23      1798         1                        Chicken Burrito
# 4522 2017-01-23      1798         1                      6 Pack Soft Drink
# 4523 2017-01-23      1798         1                     Steak Crispy Tacos
# 4524 2017-01-28      1799         1                        Chicken Burrito
# 4525 2017-01-28      1799         1                                  Chips
# 4526 2017-01-28      1799         1                      Canned Soft Drink
#
#                                      choice_description item_price  \
# 0                                                   NaN     $2.39
# 1                                          [Clementine]     $3.39
# 2                                               [Apple]     $3.39
# 3                                                   NaN     $2.39
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# 5     [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...    $10.98
# 6                                                   NaN     $1.69
# 7     [Tomatillo Red Chili Salsa, [Fajita Vegetables...    $11.75
# 8     [Tomatillo Green Chili Salsa, [Pinto Beans, Ch...     $9.25
# 9     [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...     $9.25
# 10                                                  NaN     $4.45
# 11    [Roasted Chili Corn Salsa, [Fajita Vegetables,...     $8.75
# 12    [Roasted Chili Corn Salsa, [Rice, Black Beans,...     $8.75
# 13    [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...    $11.25
# 14                                                  NaN     $4.45
# 15                                                  NaN     $2.39
# 16    [Tomatillo-Green Chili Salsa (Medium), [Pinto ...     $8.49
# 17    [Fresh Tomato Salsa (Mild), [Black Beans, Rice...     $8.49
# 18                                             [Sprite]     $2.18
# 19    [Tomatillo Red Chili Salsa, [Fajita Vegetables...     $8.75
# 20                                                  NaN     $4.45
# 21    [[Fresh Tomato Salsa (Mild), Tomatillo-Green C...     $8.99
# 22                                 [Pomegranate Cherry]     $3.39
# 23    [[Tomatillo-Green Chili Salsa (Medium), Tomati...    $10.98
# 24                                         [Grapefruit]     $3.39
# 25                                                  NaN     $2.39
# 26    [Roasted Chili Corn Salsa (Medium), [Pinto Bea...     $8.49
# 27    [[Tomatillo-Green Chili Salsa (Medium), Roaste...     $8.99
# 28                                         [Dr. Pepper]     $1.09
# 29    [Tomatillo-Green Chili Salsa (Medium), [Pinto ...     $8.49
# ...                                                 ...        ...
# 4497                                                NaN     $2.15
# 4498  [Tomatillo Green Chili Salsa, [Fajita Vegetabl...    $11.25
# 4499                                             [Coke]     $2.50
# 4500  [Roasted Chili Corn Salsa, [Rice, Black Beans,...     $9.25
# 4501                                           [Sprite]     $1.25
# 4502  [Fresh Tomato Salsa, [Cheese, Guacamole, Lettu...    $11.25
# 4503                                                NaN     $2.95
# 4504  [Fresh Tomato Salsa, [Rice, Sour Cream, Guacam...    $11.75
# 4505                                                NaN     $2.15
# 4506  [Fresh Tomato Salsa, [Rice, Cheese, Sour Cream...    $11.25
# 4507                                                NaN     $1.50
# 4508                                       [Brown Rice]     $8.99
# 4509                                                NaN     $1.99
# 4510                                        [Guacamole]    $11.49
# 4511  [Roasted Chili Corn Salsa, [Rice, Fajita Veget...     $8.75
# 4512                                                NaN     $4.45
# 4513                                        [Diet Coke]     $1.25
# 4514   [Fresh Tomato Salsa, [Rice, Cheese, Sour Cream]]     $8.75
# 4515                                                NaN     $4.45
# 4516                                           [Sprite]     $1.25
# 4517                                                NaN     $1.50
# 4518  [Tomatillo Red Chili Salsa, [Rice, Black Beans...    $11.75
# 4519  [Fresh Tomato Salsa, [Rice, Pinto Beans, Cheese]]     $8.75
# 4520                      [Fresh Tomato Salsa, Lettuce]     $8.75
# 4521  [Roasted Chili Corn Salsa, [Guacamole, Lettuce...    $11.25
# 4522                                        [Diet Coke]     $6.49
# 4523  [Tomatillo Green Chili Salsa, [Cheese, Sour Cr...    $11.75
# 4524  [Roasted Chili Corn Salsa, [Rice, Black Beans,...     $8.75
# 4525                                                NaN     $2.15
# 4526                                           [Sprite]     $1.25
#
#       item_price_float  item*quantity
# 0                 2.39           2.39
# 1                 3.39           3.39
# 2                 3.39           3.39
# 3                 2.39           2.39
# 4                16.98          33.96
# 5                10.98          10.98
# 6                 1.69           1.69
# 7                11.75          11.75
# 8                 9.25           9.25
# 9                 9.25           9.25
# 10                4.45           4.45
# 11                8.75           8.75
# 12                8.75           8.75
# 13               11.25          11.25
# 14                4.45           4.45
# 15                2.39           2.39
# 16                8.49           8.49
# 17                8.49           8.49
# 18                2.18           4.36
# 19                8.75           8.75
# 20                4.45           4.45
# 21                8.99           8.99
# 22                3.39           3.39
# 23               10.98          10.98
# 24                3.39           3.39
# 25                2.39           2.39
# 26                8.49           8.49
# 27                8.99           8.99
# 28                1.09           1.09
# 29                8.49           8.49
# ...                ...            ...
# 4497              2.15           2.15
# 4498             11.25          11.25
# 4499              2.50           5.00
# 4500              9.25           9.25
# 4501              1.25           1.25
# 4502             11.25          11.25
# 4503              2.95           2.95
# 4504             11.75          11.75
# 4505              2.15           2.15
# 4506             11.25          11.25
# 4507              1.50           1.50
# 4508              8.99           8.99
# 4509              1.99           1.99
# 4510             11.49          11.49
# 4511              8.75           8.75
# 4512              4.45           4.45
# 4513              1.25           1.25
# 4514              8.75           8.75
# 4515              4.45           4.45
# 4516              1.25           1.25
# 4517              1.50           1.50
# 4518             11.75          11.75
# 4519              8.75           8.75
# 4520              8.75           8.75
# 4521             11.25          11.25
# 4522              6.49           6.49
# 4523             11.75          11.75
# 4524              8.75           8.75
# 4525              2.15           2.15
# 4526              1.25           1.25
#
# [4527 rows x 8 columns]

# %% [markdown]
# ### Create a histogram of the top 5 items bought

# %%
p = pd.DataFrame(df.groupby('item_name', as_index = False)['quantity'].sum())
top = pd.DataFrame(p.sort_values('quantity', ascending = False)).head(5)
top.plot.bar(x = 'item_name')
top
# Out:
#               item_name  quantity
# 17         Chicken Bowl       761
# 18      Chicken Burrito       591
# 25  Chips and Guacamole       506
# 39        Steak Burrito       386
# 10    Canned Soft Drink       351

# %% [markdown]
# ### Sort the dataset by the name of the item

# %%
df.sort_values('item_name').head()
# Out:
#       order_id  quantity          item_name choice_description item_price  \
# 3389      1360         2  6 Pack Soft Drink        [Diet Coke]    $12.98
# 341        148         1  6 Pack Soft Drink        [Diet Coke]     $6.49
# 1849       749         1  6 Pack Soft Drink             [Coke]     $6.49
# 1860       754         1  6 Pack Soft Drink        [Diet Coke]     $6.49
# 2713      1076         1  6 Pack Soft Drink             [Coke]     $6.49
#
#       item_price_float  item*quantity
# 3389             12.98          25.96
# 341               6.49           6.49
# 1849              6.49           6.49
# 1860              6.49           6.49
# 2713              6.49           6.49

# %% [markdown]
# ### How many times were a Veggie Salad Bowl ordered?

# %%
df[df.item_name == 'Veggie Salad Bowl']['quantity'].sum()
# Out:
# 18

# %% [markdown]
# ### How many times people orderd more than one Canned Soda?

# %%
v1 = df[df.item_name == 'Canned Soda']
v1.head()
v1[v1.quantity > 1]['order_id'].count()
# Out:
# 20

# %% [markdown]
# ### Create a scatterplot with the number of items orderered per order price

# %%
v2 = pd.DataFrame((df.groupby('order_id')['item*quantity']).sum())
v3 = pd.DataFrame((df.groupby('order_id')['quantity']).sum())
result = pd.merge(v2, v3, on = 'order_id')
result.plot.scatter(x = 'item*quantity', y = 'quantity')

# %% [markdown]
# Submit solution to [https://goo.gl/forms/0iOA8xFJ2o5qONBr2](https://goo.gl/forms/0iOA8xFJ2o5qONBr2)
